# %%
import numpy as np
import pandas as pd

# %%
#open dataframe
df_tournament = pd.read_csv('/home/mostafa2rz/Desktop/Tennis_project/202405/df_tournament.csv')
df_tournament
# Out:
#        match_id  tournament_id  \
# 0      12315213         130001
# 1      12315541         130004
# 2      12313762         130004
# 3      12315387         130047
# 4      12311929         129921
# ...         ...            ...
# 19671  12308274         129957
# 19672  12306784         129800
# 19673  12309888         129974
# 19674  12308916         129918
# 19675  12309345         129933
#
#                                       tournament_name  \
# 0              Bucharest, Singles Main, W-ITF-ROU-01A
# 1             Valldoreix, Singles Main, M-ITF-ESP-13A
# 2             Valldoreix, Singles Main, M-ITF-ESP-13A
# 3           Platja D Aro, Singles Main, W-ITF-ESP-10A
# 4            Doboj, Singles Qualifying, M-ITF-BIH-01A
# ...                                               ...
# 19671            Tbilisi, Singles Main, M-ITF-GEO-01A
# 19672                             Mauthausen, Austria
# 19673  Zephyrhills, Singles Qualifying, W-ITF-USA-15A
# 19674    Bucharest, Singles Qualifying, W-ITF-ROU-01A
# 19675     Monastir, Singles Qualifying, M-ITF-TUN-31A
#
#                                     tournament_slug  tournament_unique_id  \
# 0              bucharest-singles-main-w-itf-rou-01a                   NaN
# 1             valldoreix-singles-main-m-itf-esp-13a                   NaN
# 2             valldoreix-singles-main-m-itf-esp-13a                   NaN
# 3           platja-d-aro-singles-main-w-itf-esp-10a                   NaN
# 4            doboj-singles-qualifying-m-itf-bih-01a                   NaN
# ...                                             ...                   ...
# 19671            tbilisi-singles-main-m-itf-geo-01a                   NaN
# 19672                            mauthausen-austria                   NaN
# 19673  zephyrhills-singles-qualifying-w-itf-usa-15a                   NaN
# 19674    bucharest-singles-qualifying-w-itf-rou-01a                   NaN
# 19675     monastir-singles-qualifying-m-itf-tun-31a                   NaN
#
#       tournament_category_name tournament_category_slug  user_count  \
# 0                    ITF Women                itf-women          22
# 1                      ITF Men                  itf-men          21
# 2                      ITF Men                  itf-men          21
# 3                    ITF Women                itf-women          32
# 4                      ITF Men                  itf-men          27
# ...                        ...                      ...         ...
# 19671                  ITF Men                  itf-men          28
# 19672               Challenger               challenger          89
# 19673                ITF Women                itf-women          33
# 19674                ITF Women                itf-women          25
# 19675                  ITF Men                  itf-men          18
#
#              ground_type  tennis_points  has_event_player_statistics  \
# 0               Red clay            NaN                        False
# 1               Red clay            NaN                        False
# 2               Red clay            NaN                        False
# 3               Red clay            NaN                        False
# 4               Red clay            NaN                         True
# ...                  ...            ...                          ...
# 19671  Hardcourt outdoor            NaN                         True
# 19672           Red clay            NaN                         True
# 19673           Red clay            NaN                        False
# 19674           Red clay            NaN                        False
# 19675  Hardcourt outdoor            NaN                         True
#
#        crowd_sourcing_enabled  has_performance_graph_feature  \
# 0                       False                          False
# 1                        True                           True
# 2                       False                           True
# 3                        True                          False
# 4                        True                           True
# ...                       ...                            ...
# 19671                   False                           True
# 19672                   False                           True
# 19673                    True                          False
# 19674                    True                           True
# 19675                   False                          False
#
#        display_inverse_home_away_teams  priority  competition_type
# 0                                False         0                 2
# 1                                 True         0                 2
# 2                                 True         0                 2
# 3                                False         0                 2
# 4                                 True         0                 2
# ...                                ...       ...               ...
# 19671                            False         0                 2
# 19672                            False         0                 2
# 19673                             True         0                 2
# 19674                             True         0                 2
# 19675                             True         0                 2
#
# [19676 rows x 16 columns]

# %%
df_match_winners = pd.read_csv('/home/mostafa2rz/Desktop/Tennis_project/Notebook/match_winner.csv')
df_match_winners
# Out:
#       Unnamed: 0  match_id match_winner  player_id
# 0              0  12260075         away   254742.0
# 1              1  12260077         away   275923.0
# 2              2  12260084         away   254742.0
# 3              3  12261530         away   106755.0
# 4              4  12261532         away   106755.0
# ...          ...       ...          ...        ...
# 6550        3336  12384674         home   134342.0
# 6551        3337  12384788         home   386338.0
# 6552        3338  12384806         home   342835.0
# 6553        3339  12384975         home    96061.0
# 6554        3340  12385017         home   254281.0
#
# [6555 rows x 4 columns]

# %%
#remove dublicate match_id from df
df_tournament = df_tournament.drop_duplicates(subset='match_id')

# add tornament_id for each match in df_match winner
df_match_winners_with_tournament = df_match_winners.merge(df_tournament[['tournament_id', 'match_id']] , on='match_id', how='left')
df_match_winners_with_tournament
# Out:
#       Unnamed: 0  match_id match_winner  player_id  tournament_id
# 0              0  12260075         away   254742.0         129164
# 1              1  12260077         away   275923.0         129164
# 2              2  12260084         away   254742.0         129164
# 3              3  12261530         away   106755.0         129164
# 4              4  12261532         away   106755.0         129164
# ...          ...       ...          ...        ...            ...
# 6550        3336  12384674         home   134342.0         131083
# 6551        3337  12384788         home   386338.0         131003
# 6552        3338  12384806         home   342835.0         131078
# 6553        3339  12384975         home    96061.0         131083
# 6554        3340  12385017         home   254281.0         131095
#
# [6555 rows x 5 columns]

# %%
#player_id who wins most tournament in this month
df_match_winners_with_tournament.groupby('player_id')['tournament_id'].count().idxmax()
# Out:
# np.float64(253356.0)
