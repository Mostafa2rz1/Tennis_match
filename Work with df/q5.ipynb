# %%
import numpy as np
import pandas as pd

# %%
df_pbp = pd.read_csv('/home/mostafa2rz/Desktop/Tennis_project/202405/df_pbp.csv')
df_pbp
# Out:
#          match_id  set_id  game_id  point_id home_point away_point  \
# 0        12315338       3        9         0          0         15
# 1        12315338       3        9         1         15         15
# 2        12315338       3        9         2         30         15
# 3        12315338       3        9         3         40         15
# 4        12315338       3        9         4         40         30
# ...           ...     ...      ...       ...        ...        ...
# 1467008  12312113       1        2         3         40         15
# 1467009  12312113       1        1         0          0         15
# 1467010  12312113       1        1         1          0         30
# 1467011  12312113       1        1         2         15         30
# 1467012  12312113       1        1         3         15         40
#
#          point_description  home_point_type  away_point_type  home_score  \
# 0                        0                5                1           6
# ...

# %%
# finall set_number(set_id) of each match
df_set_winners = df_pbp.loc[df_pbp.groupby('match_id')['set_id'].idxmax()]
df_set_winners
# Out:
#          match_id  set_id  game_id  point_id home_point away_point  \
# 1318177  12260075       2       10         0         15          0
# 1274507  12260076       3        9         0          0         15
# 1306895  12260077       3       13         0          0          1
# 701874   12260078       3        8         0         15          0
# 1278660  12260080       2       10         0          0         15
# ...           ...     ...      ...       ...        ...        ...
# 614538   12384789       2       10         0          0         15
# 623876   12384806       3        7         0         15          0
# 609745   12384892       2        6         0         15          0
# 623694   12384975       3       10         0         15          0
# 617220   12385017       3       12         0          0         15
#
#          point_description  home_point_type  away_point_type  home_score  \
# 1318177                  0                1                5           4
# ...

# %%
#median  set of each match
df_set_winners['set_id'].median()
# Out:
# np.float64(2.0)
