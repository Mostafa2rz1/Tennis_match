# %%
import pandas as pd
import pyarrow.parquet as pq
import os

# %% [markdown]
# read file in each days

# %%
folders_of_table = "Desktop/Tennis_project/202405/20240501/data/raw/"
folders_path = [os.path.join(folders_of_table, file) for file in os.listdir(folders_of_table) ]
folders_path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 folders_of_table = "Desktop/Tennis_project/202405/20240501/data/raw/"
# ----> 2 folders_path = [os.path.join(folders_of_table, file) for file in os.listdir(folders_of_table) ]
#       3 folders_path
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/Tennis_project/202405/20240501/data/raw/'

# %%
source = "/home/mostafa2rz/Desktop/Tennis_project/202405/20240501/data/raw/raw_odds_parquet"
file_paths = [os.path.join(source, file) for file in os.listdir(source) ]

df = pd.read_parquet("Desktop/Tennis_project/202405/20240501/data/raw/raw_match_parquet/away_team_12260076.parquet", engine= 'pyarrow') 
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 source = "/home/mostafa2rz/Desktop/Tennis_project/202405/20240501/data/raw/raw_odds_parquet"
#       2 file_paths = [os.path.join(source, file) for file in os.listdir(source) ]
# ----> 4 df = pd.read_parquet("Desktop/Tennis_project/202405/20240501/data/raw/raw_match_parquet/away_team_12260076.parquet", engine= 'pyarrow')
#       5 df
#
# File ~/mosi_env/lib/python3.12/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~/mosi_env/lib/python3.12/site-packages/pandas/io/parquet.py:267, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     264 if manager == "array":
#     265     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
#
# File ~/mosi_env/lib/python3.12/site-packages/pandas/io/parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)
#     138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File ~/mosi_env/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/Tennis_project/202405/20240501/data/raw/raw_match_parquet/away_team_12260076.parquet'

# %%
source = "/home/mostafa2rz/Desktop/Tennis_project/202405/20240501/data/raw/raw_odds_parquet"
file_paths = [os.path.join(source, file) for file in os.listdir(source) ]

df = [pd.read_parquet(file, engine= 'pyarrow') for file in file_paths ]
result_df = pd.concat([df[i] for i in range(len(df))], ignore_index=True)
result_df
# Out:
#       match_id  market_id market_name  is_live  suspended  \
# 0     12298718          1   full_time    False       True
# 1     12298718          1   full_time    False       True
# 2     12298279          1   full_time     True       True
# 3     12298279          1   full_time     True       True
# 4     12297590          1   full_time    False      False
# ...        ...        ...         ...      ...        ...
# 1335  12296151          1   full_time    False       True
# 1336  12298088          1   full_time    False       True
# 1337  12298088          1   full_time    False       True
# 1338  12295145          1   full_time    False      False
# 1339  12295145          1   full_time    False      False
#
#      initial_fractional_value fractional_value choice_name  choice_source_id  \
# 0                         3/2             18/3           1         410668724
# 1                         5/5             14/9           2         410668772
# 2                       19/11              6/8           1         407905399
# 3                         7/9             13/6           2         407905428
# 4                        14/2            18/11           1         406597126
# ...                       ...              ...         ...               ...
# 1335                    13/10             16/2           2         403464758
# 1336                      5/8             2/11           1         407470540
# 1337                     15/5              8/3           2         407470580
# 1338                      5/4              2/7           1         400003456
# 1339                      8/9              6/8           2         400003556
#
#      winnig  change
# 0      True       0
# 1     False       0
# 2      True       0
# 3     False       0
# 4     False       0
# ...     ...     ...
# 1335   True       0
# 1336  False       0
# 1337  False       0
# 1338  False       0
# 1339   True       0
#
# [1340 rows x 11 columns]

# %%
source = "/home/mostafa2rz/Desktop/Tennis_project/202405"
folder_list = os.listdir(source)
folders_of_date = [os.path.join(source , file) for file in folder_list  ]
folders_of_date
# Out:
# ['/home/mostafa2rz/Desktop/Tennis_project/202405/20240507',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240512',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240529',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240524',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240511',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240523',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240521',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240513',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240526',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240516',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240504',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240510',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240527',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240505',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240531',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240520',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240502',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240508',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240518',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240522',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240515',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240519',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240525',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240509',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240528',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240514',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240517',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240501',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240503',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240530',
#  '/home/mostafa2rz/Desktop/Tennis_project/202405/20240506']

# %%
source = "/home/mostafa2rz/Desktop/Tennis_project/202405"
folder_list = os.listdir(source)
folders_of_date = [os.path.join(source , file) for file in folder_list  ]
dfs = {}
for folder , list in folders_of_date , folder_list :
    folders_of_table = folder + "/data/raw"
    tables_path = [os.path.join(folders_of_table, file) for file in os.listdir(folders_of_table) ]
    i = 0
    for table in tables_path:
    
        file_paths = [os.path.join(table, file) for file in os.listdir(table) ]
        df = [pd.read_parquet(file, engine= 'pyarrow') for file in file_paths ]
        result_df = pd.concat([df[i] for i in range(len(df))], ignore_index=True)
        result_df['date'] = list
        dfs[f'df_{i}'] = result_df
        for i in range(len(dfs)):
            exec(f"df_{i} = dfs['df_{i}']")
        i += 1

    
    df[list] =pd.concat([df_0[k] for k in range(len(list))], ignore_index=True)
    df[list] =pd.concat([df_1[k] for k in range(len(list))], ignore_index=True)
    df[list] =pd.concat([df_2[k] for k in range(len(list))], ignore_index=True)
    df[list] =pd.concat([df_3[k] for k in range(len(list))], ignore_index=True)
    df[list] =pd.concat([df_4[k] for k in range(len(list))], ignore_index=True)
    df[list] =pd.concat([df_5[k] for k in range(len(list))], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 5
#       3 folders_of_date = [os.path.join(source , file) for file in folder_list  ]
#       4 dfs = {}
# ----> 5 for folder , list in folders_of_date , folder_list :
#       6     folders_of_table = folder + "/data/raw"
#       7     tables_path = [os.path.join(folders_of_table, file) for file in os.listdir(folders_of_table) ]
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# this method is expierd

# %%
    for x in range(len(dfs)):
        dfx[f'df_{list}'] = pd.concat([dfs['df_{x}'] for k in range(len(list))], ignore_index=True)
        exec(f"df_{x} = dfs['df_{x}']")
# Out:
# /tmp/ipykernel_15931/2879743630.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat([df[i] for i in range(len(df))], ignore_index=True)
# df_0:
#        match_id  set_id  game_id  point_id home_point away_point  \
# 0      12291702       3        9         0          0         15
# 1      12291702       3        9         1          0         30
# 2      12291702       3        9         2         15         30
# 3      12291702       3        9         3         15         40
# 4      12291702       3        8         0          0         15
# ...         ...     ...      ...       ...        ...        ...
# 62309  12295593       1        1         0          0         15
# 62310  12295593       1        1         1         15         15
# 62311  12295593       1        1         2         15         30
# 62312  12295593       1        1         3         30         30
# 62313  12295593       1        1         4         30         40
#
#        point_description  home_point_type  away_point_type  home_score  \
# 0                      0                5                1           3
# 1                      0                5                1           3
# 2                      0                1                5           3
# 3                      0                5                3           3
# 4                      0                5                1           3
# ...                  ...              ...              ...         ...
# 62309                  0                5                1           0
# 62310                  0                1                5           0
# 62311                  0                5                1           0
# 62312                  0                1                5           0
# 62313                  0                5                1           0
#
#        away_score  serving  scoring      date
# 0               6        2        2  20240501
# 1               6        2        2  20240501
# 2               6        2        2  20240501
# 3               6        2        2  20240501
# 4               5        1        2  20240501
# ...           ...      ...      ...       ...
# 62309           1        2        2  20240501
# 62310           1        2        2  20240501
# 62311           1        2        2  20240501
# 62312           1        2        2  20240501
# 62313           1        2        2  20240501
#
# [62314 rows x 14 columns]
#
#
# df_1:
#      match_id  home_vote  away_vote      date
# 0    12295046         34          6  20240501
# 1    12291702        126        334  20240501
# 2    12287007         62        586  20240501
# 3    12293730          0         26  20240501
# 4    12297641         22         58  20240501
# ..        ...        ...        ...       ...
# 591  12293758         44         14  20240501
# 592  12295538          0          0  20240501
# 593  12298151         42          2  20240501
# 594  12292490         36         40  20240501
# 595  12293470         12         42  20240501
#
# [596 rows x 4 columns]
#
#
# df_2:
#       match_id  market_id market_name  is_live  suspended  \
# 0     12298718          1   full_time    False       True
# 1     12298718          1   full_time    False       True
# 2     12298279          1   full_time     True       True
# 3     12298279          1   full_time     True       True
# 4     12297590          1   full_time    False      False
# ...        ...        ...         ...      ...        ...
# 1335  12296151          1   full_time    False       True
# 1336  12298088          1   full_time    False       True
# 1337  12298088          1   full_time    False       True
# 1338  12295145          1   full_time    False      False
# 1339  12295145          1   full_time    False      False
#
#      initial_fractional_value fractional_value choice_name  choice_source_id  \
# 0                         3/2             18/3           1         410668724
# 1                         5/5             14/9           2         410668772
# 2                       19/11              6/8           1         407905399
# 3                         7/9             13/6           2         407905428
# 4                        14/2            18/11           1         406597126
# ...                       ...              ...         ...               ...
# 1335                    13/10             16/2           2         403464758
# 1336                      5/8             2/11           1         407470540
# 1337                     15/5              8/3           2         407470580
# 1338                      5/4              2/7           1         400003456
# 1339                      8/9              6/8           2         400003556
#
#      winnig  change      date
# 0      True       0  20240501
# 1     False       0  20240501
# 2      True       0  20240501
# 3     False       0  20240501
# 4     False       0  20240501
# ...     ...     ...       ...
# 1335   True       0  20240501
# 1336  False       0  20240501
# 1337  False       0  20240501
# 1338  False       0  20240501
# 1339   True       0  20240501
#
# [1340 rows x 12 columns]
#
#
# df_3:
#        match_id period statistic_category_name              statistic_name  \
# 0      12297674    ALL                 service                        aces
# 1      12297674    ALL                 service               double_faults
# 2      12297674    ALL                 service                 first_serve
# 3      12297674    ALL                 service                second_serve
# 4      12297674    ALL                 service          first_serve_points
# ...         ...    ...                     ...                         ...
# 32818  12293472    2ND                  return   first_serve_return_points
# 32819  12293472    2ND                  return  second_serve_return_points
# 32820  12293472    2ND                  return         return_games_played
# 32821  12293472    2ND                  return      break_points_converted
# 32822  12293472    2ND           miscellaneous                   tiebreaks
#
#          home_stat     away_stat  compare_code statistic_type value_type  \
# 0                1             0             1       positive      event
# 1                4             3             1       negative      event
# 2      43/88 (49%)  92/110 (84%)             2       positive       team
# 3      41/45 (91%)   15/18 (83%)             1       positive       team
# 4      25/43 (58%)   54/92 (59%)             2       positive       team
# ...            ...           ...           ...            ...        ...
# 32818    4/9 (44%)    6/26 (23%)             1       positive       team
# 32819   8/13 (61%)   11/17 (64%)             2       positive       team
# 32820            3             4             2       positive      event
# 32821            2             0             1       positive      event
# 32822            0             0             3       positive      event
#
#        home_value  away_value  home_total  away_total      date
# 0               0           0         NaN         NaN  20240501
# 1               2           4         NaN         NaN  20240501
# 2              76         118        88.0       110.0  20240501
# 3              10           8        45.0        18.0  20240501
# 4              12           2        43.0        92.0  20240501
# ...           ...         ...         ...         ...       ...
# 32818           0          10         9.0        26.0  20240501
# 32819          14           6        13.0        17.0  20240501
# 32820           2           2         NaN         NaN  20240501
# 32821           0           0         NaN         NaN  20240501
# 32822           0           0         NaN         NaN  20240501
#
# [32823 rows x 14 columns]
#
#
# df_4:
#        match_id  set_num  game_num  value  break_occurred      date
# 0      12295833        1         1   0.00            True  20240501
# 1      12295833        1         2 -35.20            True  20240501
# 2      12295833        1         3   2.00            True  20240501
# 3      12295833        1         4   6.00            True  20240501
# 4      12295833        1         5   0.00           False  20240501
# ...         ...      ...       ...    ...             ...       ...
# 11340  12298445        2         6  18.18           False  20240501
# 11341  12298445        2         7  19.14            True  20240501
# 11342  12298445        2         8 -26.42           False  20240501
# 11343  12298445        2         9 -22.56           False  20240501
# 11344  12298445        2        10   2.00           False  20240501
#
# [11345 rows x 6 columns]
#
#
# df_5:
#       match_id  round_id                                     name  \
# 0     12295106       6.0                              Round of 32
# 1     12291706       NaN                                      NaN
# 2     12293459       NaN                                      NaN
# 3     12293564       6.0                              Round of 32
# 4     12293734       NaN  ITF Great Britain F10, Men Singles 2024
# ...        ...       ...                                      ...
# 5735  12293541       NaN                                      NaN
# 5736  12292878       NaN                                      NaN
# 5737  12295820       NaN                                      NaN
# 5738  12293537       NaN                                      NaN
# 5739  12288048       NaN                                Arango E.
#
#                  slug  cup_round_type  tournament_id tournament_name  \
# 0         round-of-32            16.0            NaN             NaN
# 1                 NaN             NaN       129531.0   Lleida, Spain
# 2                 NaN             NaN            NaN             NaN
# 3         round-of-32            16.0            NaN             NaN
# 4                 NaN             NaN            NaN             NaN
# ...               ...             ...            ...             ...
# 5735              NaN             NaN            NaN             NaN
# 5736              NaN             NaN            NaN             NaN
# 5737              NaN             NaN            NaN             NaN
# 5738              NaN             NaN            NaN             NaN
# 5739  arango-emiliana             NaN            NaN             NaN
#
#      tournament_slug tournament_unique_id tournament_category_name  ...  \
# 0                NaN                  NaN                      NaN  ...
# 1       lleida-spain                 None         Challenger Women  ...
# 2                NaN                  NaN                      NaN  ...
# 3                NaN                  NaN                      NaN  ...
# 4                NaN                  NaN                      NaN  ...
# ...              ...                  ...                      ...  ...
# 5735             NaN                  NaN                      NaN  ...
# 5736             NaN                  NaN                      NaN  ...
# 5737             NaN                  NaN                      NaN  ...
# 5738             NaN                  NaN                      NaN  ...
# 5739             NaN                  NaN                      NaN  ...
#
#      total_prize  player_id current_rank  name_code   country  \
# 0            NaN        NaN          NaN        NaN       NaN
# 1            NaN        NaN          NaN        NaN       NaN
# 2            NaN        NaN          NaN        NaN       NaN
# 3            NaN        NaN          NaN        NaN       NaN
# 4            NaN        NaN          NaN        NaN       NaN
# ...          ...        ...          ...        ...       ...
# 5735         NaN        NaN          NaN        NaN       NaN
# 5736         NaN        NaN          NaN        NaN       NaN
# 5737         NaN        NaN          NaN        NaN       NaN
# 5738         NaN        NaN          NaN        NaN       NaN
# 5739    382565.0   198197.0        115.0        ARA  Colombia
#
#              full_name city stadium  venue_id      date
# 0                  NaN  NaN     NaN       NaN  20240501
# 1                  NaN  NaN     NaN       NaN  20240501
# 2                  NaN  NaN     NaN       NaN  20240501
# 3                  NaN  NaN     NaN       NaN  20240501
# 4                  NaN  NaN     NaN       NaN  20240501
# ...                ...  ...     ...       ...       ...
# 5735               NaN  NaN     NaN       NaN  20240501
# 5736               NaN  NaN     NaN       NaN  20240501
# 5737               NaN  NaN     NaN       NaN  20240501
# 5738               NaN  NaN     NaN       NaN  20240501
# 5739  Arango, Emiliana  NaN     NaN       NaN  20240501
#
# [5740 rows x 63 columns]

# %%
for i in range(len(dfs)):
    exec(f"df_{i} = dfs['df_{i}']")
df_1
# Out:
#      match_id  home_vote  away_vote      date
# 0    12295046         34          6  20240501
# 1    12291702        126        334  20240501
# 2    12287007         62        586  20240501
# 3    12293730          0         26  20240501
# 4    12297641         22         58  20240501
# ..        ...        ...        ...       ...
# 591  12293758         44         14  20240501
# 592  12295538          0          0  20240501
# 593  12298151         42          2  20240501
# 594  12292490         36         40  20240501
# 595  12293470         12         42  20240501
#
# [596 rows x 4 columns]
